# %% [markdown]
# <a href="https://colab.research.google.com/github/engrsakib/AI-ML-Learning/blob/AI-ML/Module_08_ML_Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 05, 06 & 07 Assignment
# ## Understanding the ML Problem, Exploratory Data Analysis (EDA) and Basic Preprocessing
# **Dataset:** Titanic – Machine Learning from Disaster (Kaggle)
#
# Download the **train.csv** file from Kaggle’s Titanic competition and upload it to this notebook. Rename it to `titanic.csv` or update the file name in the loading cell.
# Dataset link: https://www.kaggle.com/datasets/yasserh/titanic-dataset
#
# Total Marks: **100**

# %% [markdown]
# ### Instructions
# - This assignment covers:
#   - **Module 05:** Basic ML problem framing (features, target, task type).
#   - **Module 06:** Exploratory Data Analysis (EDA).
#   - **Module 07:** Basic Preprocessing (handling missing values, encoding, scaling).
# - Answer all questions inside this notebook using code and markdown.
# - Do not delete the original question texts.
# - At the end, the notebook should run from top to bottom without errors.

# %%
# ==============================
# Setup
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler

sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (8, 5)

print("Libraries imported.")
# Out:
# Libraries imported.

# %% [markdown]
# ---
# ## Part 0: Understanding the ML Problem (Module 05) – 10 marks
#
# ### 0.1 Load the Dataset and Inspect (5 marks)
# **Tasks:**
# 1. Load `titanic.csv` into a pandas DataFrame.
# 2. Show `.head()`, `.info()`, and `.describe()`.
# 3. Briefly look at the column names and data types.

# %%
# 0.1 Load the Dataset and Inspect
# TODO: Change file name if needed.

df = pd.read_csv("titanic.csv")#Download the .csv file from Kaggle

print("Shape of dataset:", df.shape)
display(df.head())

print("\nInfo:")
print(df.info())

print("\nDescribe (numeric columns):")
display(df.describe())
# Out:
# Shape of dataset: (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# Describe (numeric columns):
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### 0.2 Identify Features, Target and Task Type (5 marks)
# **Tasks:**
# Based on the dataset:
# 1. Identify the **target variable** for a predictive model.
# 2. List at least **5 potential feature columns** you could use.
# 3. State whether this is a **classification** or **regression** problem, and explain **why**.
#
# Write your answers below.

# %% [markdown]
# #### **Your answers**
# - Target variable:
#     Survived — 0 (did not survive) or 1 (survived). We will predict if a passenger lived or died.
# - Feature columns (at least 5):
#   * Sex
#   * Age
#   * SibSp
#   * Parch
#   * Fare
#
# - Is this classification or regression, and why?
#
#    Sex: Women were given priority during the rescue, making gender the most critical factor for survival.
#
#   Age: Children and infants were prioritized for lifeboats, so age directly impacted survival chances.
#
#   SibSp: Having siblings or a spouse determined whether a passenger had support or had to help others during the chaos.
#
#   Parch: Passengers traveling with parents or children behaved differently (e.g., parents saving children), which affected survival.
#
#   Fare: People who paid higher fares (1st Class) had cabins closer to the lifeboats and survived more often.

# %% [markdown]
# ---
# ## Part A: Exploratory Data Analysis (EDA) – 45 marks
#
# ### 1. Initial Exploration and Cleaning Decisions (10 marks)
# **Tasks:**
# 1. Show the number of unique values in each column.
# 2. Identify columns that are clearly **IDs or high-cardinality text** (for example, `PassengerId`, `Name`, `Ticket`).
# 3. Decide which of these columns you will **drop** for the rest of the analysis and justify in 2–3 sentences.

# %%
# 1. Initial Exploration and Cleaning Decisions (Task 1 is given)
print("Unique values per column:")
for col in df.columns:
    print(col, ":", df[col].nunique())
# Out:
# Unique values per column:
# PassengerId : 891
# Survived : 2
# Pclass : 3
# Name : 891
# Sex : 2
# Age : 88
# SibSp : 7
# Parch : 7
# Ticket : 681
# Fare : 248
# Cabin : 147
# Embarked : 3

# %% [markdown]
# #### Columns to drop and justification
# - Columns dropped:
#     * PassengerId
#     * Name
#     * Ticket
#     * Cabin
# - Justification (2–3 sentences):
#   * PassengerId is only an ID number for each person. It doesn't help the model learn who survived, so we remove it.
#   * Name and Ticket are long text with many different values and are noisy. They won't help a simple model unless we do extra work (like taking the title from the Name), so we drop them for now.
#   * Cabin has lots of missing values, so it's unreliable. We could try to use deck info later, but for a basic model we remove it.

# %% [markdown]
# ---
# ### 2. Univariate Analysis (15 marks)
# **Tasks:**
# - Plot histograms for numeric features: `Age`, `Fare`, `SibSp`, `Parch`.
# - Plot countplots for categorical features: `Sex`, `Pclass`, `Embarked`.
# - Write **two to three insights** about the distributions and any obvious patterns.

# %%
# 2. Univariate Analysis

numeric_cols = ["Age", "Fare", "SibSp", "Parch"]

# Histograms code is written for you
df[numeric_cols].hist(bins=20, figsize=(10, 6))
plt.tight_layout()
plt.show()

print()
# Write Countplots code for key categorical variables [You need to complete]
cat_cols = ["Sex", "Pclass", "Embarked"]

fig, axes = plt.subplots(1, len(cat_cols), figsize=(12, 4))
for ax, col in zip(axes, cat_cols):
    sns.countplot(x=col, hue=col, data=df, ax=ax, palette="pastel", dodge=False)
    if ax.get_legend() is not None:
        ax.get_legend().remove()
    ax.set_title(f"Count of {col}")
    ax.set_xlabel(col)
    ax.set_ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Write Your insights
# - Insight 1:   The charts show that there were more men than women on the ship. Most people were in 3rd class, which was probably the cheapest. Fewer people were in 1st and 2nd class.
#
# - Insight 2:  Most passengers were young, around 20 to 30 years old. The ticket price chart shows that most people paid little money. Only a few paid a lot.
#
#
# - Insight 3:  Most people were alone on the ship with no family. The highest bar is at 0, which means no siblings, wife, or parents. Only a few had family with them.

# %% [markdown]
# ---
# ### 3. Bivariate Analysis with Target (15 marks)
# Use `Survived` as the target variable.
#
# **Tasks:**
# - Compute and plot a **correlation heatmap** for numeric features, including `Survived`.
# - Create a **pairplot** for: `Age`, `Fare`, `SibSp`, `Parch`, and `Survived`.
# - Write **two to three insights**, including which variables seem associated with survival.

# %%
# 3. Bivariate Analysis with Target

num_for_corr = ["Survived", "Age", "Fare", "SibSp", "Parch"]
## Complete this code block to generate correlation heatmap and pairplot [You need to complete]
# 3. Bivariate Analysis with Target
corr = df[num_for_corr].corr()
plt.figure(figsize=(6, 5))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", vmin=-1, vmax=1, linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

print()

# Pairplot
plot_cols = ["Age", "Fare", "SibSp", "Parch"]
df_pair = df[plot_cols + ["Survived"]].copy()

df_pair["Survived"] = df_pair["Survived"].map({0: "No", 1: "Yes"})
sns.pairplot(df_pair, vars=plot_cols, hue="Survived", palette={"No":"tab:blue","Yes":"tab:orange"}, diag_kind="kde")
plt.suptitle("Pairplot by Survival", y=1.02)
plt.show()

# %% [markdown]
# #### Your insights
# - Insight 1:  The age distribution analysis reveals a distinct survival advantage for infants and young children, evidenced by the density peak of survivors in the lower age brackets. This aligns with historical accounts of "women and children first" protocols.
#
#
# - Insight 2:  A strong positive correlation is observed between ticket fare and survival probability. The scatter plots demonstrate that passengers in higher fare brackets were significantly more likely to survive, suggesting a socioeconomic disparity in rescue outcomes.
#
# - Insight 3:  The multivariate analysis of family attributes (SibSp and Parch) indicates that while the majority of passengers traveled alone, large family sizes did not correlate with higher survival rates. In fact, smaller family units appeared to have slightly better outcomes compared to large families.

# %% [markdown]
# ---
# ### 4. Categorical vs Target Analysis (5 marks)
# **Tasks:**
# For each of the following categorical features: `Sex`, `Pclass`, `Embarked`:
# - Plot a **bar chart** showing the proportion of passengers who survived in each category.
# - Write **two short insights** about which categories have higher or lower survival chances.

# %%
# 4. Categorical vs Target Analysis [Bar chart code is written for you]

cat_target_cols = ["Sex", "Pclass", "Embarked"]

for c in cat_target_cols:
    ct = pd.crosstab(df[c], df["Survived"], normalize="index")
    print(f"\nSurvival proportion by {c}:")
    display(ct)
    ct.plot(kind="bar", stacked=True)
    plt.title(f"Survival proportion by {c}")
    plt.ylabel("Proportion")
    plt.xticks(rotation=0)
    plt.tight_layout()
    plt.show()
# Out:
# Survival proportion by Sex:
# Survived         0         1
# Sex
# female    0.257962  0.742038
# male      0.811092  0.188908
# Survival proportion by Pclass:
# Survived         0         1
# Pclass
# 1         0.370370  0.629630
# 2         0.527174  0.472826
# 3         0.757637  0.242363
# Survival proportion by Embarked:
# Survived         0         1
# Embarked
# C         0.446429  0.553571
# Q         0.610390  0.389610
# S         0.663043  0.336957

# %% [markdown]
# #### Your insights
# - Insight 1:   The "Sex" chart tells us the most important story about survival. The tall orange bar for females shows that almost 74% of women were saved, which is a huge number. On the other hand, the big blue bar for men means that most men unfortunately died. This happened because the captain and crew followed the strict rule of "women and children first" to save them before the men.
#
# - Insight 2:  Money and boarding location played a big role in who lived or died. The charts show that rich passengers in 1st class had the highest chance of surviving (over 60%), while poor people in 3rd class sadly had a very hard time escaping. This connects to the "Embarked" chart, where people from Port C survived the most—likely because many rich people boarded there. In contrast, passengers from Port S had the lowest survival rate, probably because many poor workers and families boarded there.

# %% [markdown]
# ---
# ## Part B: Basic Data Preprocessing – 45 marks
#
# Focus: **Handling missing values, encoding categorical variables, and scaling numeric features.**

# %% [markdown]
# ### 5. Handling Missing Values (15 marks)
# **Tasks:**
# 1. Show the count of missing values in each column.
# 2. Decide how to handle missing values for:
#    - `Age` (numeric)
#    - `Embarked` (categorical)
#    - `Cabin` (many missing values)
# 3. Implement your chosen strategy in code.
# 4. Show missing value counts again to confirm.
# 5. Explain your choices in **3–4 sentences**.

# %%
# 5. Handling Missing Values

print("Missing values before:") #[Task 1 is done for you]
print(df.isna().sum())

# Drop Cabin (Complete this code block)
df.drop(columns=['Cabin'], errors='ignore', inplace=True)

# Fill Age (Complete this code block)
df['Age'] = df['Age'].fillna(df['Age'].median())

# Fill Embarked (Complete this code block)
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

print("\nMissing values after handling:")
print(df.isna().sum())
# Out:
# Missing values before:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64
#
# Missing values after handling:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# #### Explanation of your strategy
# - Why you dropped or kept `Cabin`:  I dropped the 'Cabin' column because it had a huge amount of missing data (687 rows). Since more than half of the information was missing, it was too empty to be useful for the model.
# - Why you used median/mean for `Age`:  I used the median because it picks the middle age and isn't messed up by very old or very young outliers. It gives a safer guess for the missing ages compared to the average.
# - Why you used mode or another method for `Embarked`:  Since 'Embarked' is text (port names) and not numbers, I couldn't do math like average. I used the mode to pick the most common port because it's the most likely place where those passengers boarded.

# %% [markdown]
# ---
# ### 6. Encoding Categorical Variables (15 marks)
# Focus on the following categorical features:
# - `Sex`
# - `Embarked`
# - `Pclass` (treat as categorical)
#
# **Tasks:**
# - Use `OneHotEncoder` from sklearn to encode these features.
# - Keep `Survived` and the main numeric features (`Age`, `Fare`, `SibSp`, `Parch`).
# - Show the shape and head of the encoded DataFrame.

# %%
# 6. Encoding Categorical Variables

df_enc = df.copy()

# Select features for encoding and keep important numeric ones
cat_features = ["Sex", "Embarked", "Pclass"]
numeric_features = ["Age", "Fare", "SibSp", "Parch"]
target_col = "Survived"

# One hot encode categorical variables [You need to do]
encoded_df = pd.get_dummies(df_enc[cat_features], drop_first=True)

# Build final encoded DataFrame
df_model = pd.concat([
    df_enc[[target_col] + numeric_features],
    encoded_df
], axis=1)

print("Shape after encoding:", df_model.shape)
display(df_model.head())
# Out:
# Shape after encoding: (891, 9)
#    Survived   Age     Fare  SibSp  Parch  Pclass  Sex_male  Embarked_Q  \
# 0         0  22.0   7.2500      1      0       3      True       False
# 1         1  38.0  71.2833      1      0       1     False       False
# 2         1  26.0   7.9250      0      0       3     False       False
# 3         1  35.0  53.1000      1      0       1     False       False
# 4         0  35.0   8.0500      0      0       3      True       False
#
#    Embarked_S
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True

# %% [markdown]
# ---
# ### 7. Scaling Numeric Features (15 marks)
# **Tasks:**
# - Use `StandardScaler` on the numeric features: `Age`, `Fare`, `SibSp`, `Parch`.
# - Plot boxplots of these features **before** and **after** scaling.
# - Write **two sentences** explaining how scaling changes the numeric values and why it is useful before training some ML models.

# %%
# 7. Scaling Numeric Features

score_cols = ["Age", "Fare", "SibSp", "Parch"]

# Boxplot before scaling
plt.figure(figsize=(6, 4))
sns.boxplot(data=df_model[score_cols])
plt.title("Numeric features before scaling")
plt.tight_layout()
plt.show()

# Apply StandardScaler [You need to do]
scaler = StandardScaler()
df_scaled = df_model.copy()
df_scaled[score_cols] = scaler.fit_transform(df_model[score_cols])

# Boxplot after scaling
plt.figure(figsize=(6, 4))
sns.boxplot(data=df_scaled[score_cols])
plt.title("Numeric features after StandardScaler")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Your observations on scaling
# - Sentence 1:  StandardScaler changes the data so all features are on the same scale, with a mean of 0 and standard deviation of 1. This helps the model treat each feature fairly, no matter if the values are big or small.
# - Sentence 2:  This makes sure that features like Fare don’t overpower smaller ones like Age or SibSp when training the model.

# %% [markdown]
# ---
# ### 8. Simple Feature Quality Check (5 marks)
# **Tasks:**
# - Show `.info()` of the final processed DataFrame (`df_scaled`).
# - Confirm there are no missing values.
# - Confirm that all remaining features are numeric and suitable for most ML models.
# - Write **one short concluding remark** about dataset readiness.

# %%
# 8. Simple Feature Quality Check
print(df_scaled.info())

print("\nTotal missing values in final DataFrame:", df_scaled.isna().sum().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Age         891 non-null    float64
#  2   Fare        891 non-null    float64
#  3   SibSp       891 non-null    float64
#  4   Parch       891 non-null    float64
#  5   Pclass      891 non-null    int64
#  6   Sex_male    891 non-null    bool
#  7   Embarked_Q  891 non-null    bool
#  8   Embarked_S  891 non-null    bool
# dtypes: bool(3), float64(4), int64(2)
# memory usage: 44.5 KB
# None
#
# Total missing values in final DataFrame: 0

# %% [markdown]
# #### Final remark on dataset readiness
# - Your remark:

# %% [markdown]
# ---
# ## Submission
# - Run all cells from top to bottom to make sure everything works.
# - Set the Colab file's shareable link to ‘Anyone with the link’ and ‘View’ access, then submit it in the Phitron Assignment module's Assignment submission section.
