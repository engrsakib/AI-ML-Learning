# %%
data = '''
This is a multi-line string.
It can span multiple lines.
Useful for documentation or large text blocks.
'''

name = "John Doe"
print(data)

process = name.lower()
print(process)

print(process.find("Doe"))

### Variable Naming Rules
print(data[2], "index")
# Out:
# This is a multi-line string.
# It can span multiple lines.
# Useful for documentation or large text blocks.
#
# john doe
# -1
# h index
