# %% [markdown]
# <a href="https://colab.research.google.com/github/engrsakib/AI-ML-Learning/blob/AI-ML/MLTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a:int = 20;
a = "sa"
print(a);

st = set([2,5,3,5,33,3,2,1])

print(st)
# Out:
# sa
# {33, 2, 3, 1, 5}
