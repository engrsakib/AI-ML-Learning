# %% [markdown]
# <a href="https://colab.research.google.com/github/engrsakib/AI-ML-Learning/blob/AI-ML/students.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah"],
    "City": ["New York", "Los Angeles", "Newark", "Boston", "New Delhi", "Chicago", "New Orleans", "Houston"], # "Houston" আপডেট করা হয়েছে
    "Department": ["HR", "IT", "Finance", "IT", "HR", "Marketing", "Finance", "HR"],
    "Salary": [50000, 60000, 55000, 70000, 52000, 58000, 62000, 51000]
}

# 'data' ডিকশনারি থেকে একটি ডেটাফ্রেম তৈরি করা
df = pd.DataFrame(data)

# ডেটাফ্রেমটি প্রিন্ট করা (এটি আপনার ছবির মতো আউটপুট দেবে)
print(df)
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 1      Bob  Los Angeles         IT   60000
# 2  Charlie       Newark    Finance   55000
# 3    David       Boston         IT   70000
# 4      Eve    New Delhi         HR   52000
# 5    Frank      Chicago  Marketing   58000
# 6    Grace  New Orleans    Finance   62000
# 7   Hannah      Houston         HR   51000
